# %%
import gymnasium as gym
from time import sleep
import random

# %%
env = gym.make('MountainCar-v0')

# %%
env.reset()
env.render()

# %%
seed= 0
random.seed(seed)

# %%
print(f'Action space: {env.action_space}')
# Out:
# Action space: Discrete(3)

# %%
episodes = 10
reward_sum = 0

# %%
env.observation_space
# Out:
# Box([-1.2  -0.07], [0.6  0.07], (2,), float32)

# %%
for i in  range(episodes):
    init_state = env.reset()
    reward_sum = 0

# %%
from time import sleep
import gymnasium as gym
import random
env = gym.make('MountainCar-v0', render_mode='human')

seed = 0
random.seed(seed)

print(f'Action Space: {env.action_space}')
print(f'Observation Space: {env.observation_space}')

episodes = 100
reward_sum = 0
for i in range(episodes):
    init_state = env.reset()
    env.render()
    random_action = random.randint(0, 2)
    state, reward,truncated,done,info = env.step(random_action)

    print(f'Action Space: {env.action_space}')
    print(f'Observation Space: {env.observation_space}')

    reward_sum += reward
    sleep(.01)
    if done:
        print(f'Episode {i} reward: {reward_sum}')
        sleep(1)
        break
env.close()
# Out:
# Action Space: Discrete(3)
# Observation Space: Box([-1.2  -0.07], [0.6  0.07], (2,), float32)
# Action Space: Discrete(3)
# Observation Space: Box([-1.2  -0.07], [0.6  0.07], (2,), float32)
# Action Space: Discrete(3)
# Observation Space: Box([-1.2  -0.07], [0.6  0.07], (2,), float32)
# Action Space: Discrete(3)
# Observation Space: Box([-1.2  -0.07], [0.6  0.07], (2,), float32)
# Action Space: Discrete(3)
# Observation Space: Box([-1.2  -0.07], [0.6  0.07], (2,), float32)
# Action Space: Discrete(3)
# Observation Space: Box([-1.2  -0.07], [0.6  0.07], (2,), float32)
# Action Space: Discrete(3)
# Observation Space: Box([-1.2  -0.07], [0.6  0.07], (2,), float32)
# Action Space: Discrete(3)
# Observation Space: Box([-1.2  -0.07], [0.6  0.07], (2,), float32)
# Action Space: Discrete(3)
# Observation Space: Box([-1.2  -0.07], [0.6  0.07], (2,), float32)
# Action Space: Discrete(3)
# Observation Space: Box([-1.2  -0.07], [0.6  0.07], (2,), float32)
# Action Space: Discrete(3)
# Observation Space: Box([-1.2  -0.07], [0.6  0.07], (2,), float32)
# Action Space: Discrete(3)
# Observation Space: Box([-1.2  -0.07], [0.6  0.07], (2,), float32)
# Action Space: Discrete(3)
# Observation Space: Box([-1.2  -0.07], [0.6  0.07], (2,), float32)
# Action Space: Discrete(3)
# Observation Space: Box([-1.2  -0.07], [0.6  0.07], (2,), float32)
# Action Space: Discrete(3)
# Observation Space: Box([-1.2  -0.07], [0.6  0.07], (2,), float32)
# Action Space: Discrete(3)
# Observation Space: Box([-1.2  -0.07], [0.6  0.07], (2,), float32)
# Action Space: Discrete(3)
# Observation Space: Box([-1.2  -0.07], [0.6  0.07], (2,), float32)
# Action Space: Discrete(3)
# Observation Space: Box([-1.2  -0.07], [0.6  0.07], (2,), float32)
# Action Space: Discrete(3)
# Observation Space: Box([-1.2  -0.07], [0.6  0.07], (2,), float32)
# Action Space: Discrete(3)
# Observation Space: Box([-1.2  -0.07], [0.6  0.07], (2,), float32)
# Action Space: Discrete(3)
# Observation Space: Box([-1.2  -0.07], [0.6  0.07], (2,), float32)
# Action Space: Discrete(3)
# Observation Space: Box([-1.2  -0.07], [0.6  0.07], (2,), float32)
# Action Space: Discrete(3)
# Observation Space: Box([-1.2  -0.07], [0.6  0.07], (2,), float32)
# Action Space: Discrete(3)
# Observation Space: Box([-1.2  -0.07], [0.6  0.07], (2,), float32)
# Action Space: Discrete(3)
# Observation Space: Box([-1.2  -0.07], [0.6  0.07], (2,), float32)
# Action Space: Discrete(3)
# Observation Space: Box([-1.2  -0.07], [0.6  0.07], (2,), float32)
# Action Space: Discrete(3)
# Observation Space: Box([-1.2  -0.07], [0.6  0.07], (2,), float32)
# Action Space: Discrete(3)
# Observation Space: Box([-1.2  -0.07], [0.6  0.07], (2,), float32)
# Action Space: Discrete(3)
# Observation Space: Box([-1.2  -0.07], [0.6  0.07], (2,), float32)
# Action Space: Discrete(3)
# Observation Space: Box([-1.2  -0.07], [0.6  0.07], (2,), float32)
# Action Space: Discrete(3)
# Observation Space: Box([-1.2  -0.07], [0.6  0.07], (2,), float32)
# Action Space: Discrete(3)
# Observation Space: Box([-1.2  -0.07], [0.6  0.07], (2,), float32)
# Action Space: Discrete(3)
# Observation Space: Box([-1.2  -0.07], [0.6  0.07], (2,), float32)
# Action Space: Discrete(3)
# Observation Space: Box([-1.2  -0.07], [0.6  0.07], (2,), float32)
# Action Space: Discrete(3)
# Observation Space: Box([-1.2  -0.07], [0.6  0.07], (2,), float32)
# Action Space: Discrete(3)
# Observation Space: Box([-1.2  -0.07], [0.6  0.07], (2,), float32)
# Action Space: Discrete(3)
# Observation Space: Box([-1.2  -0.07], [0.6  0.07], (2,), float32)
# Action Space: Discrete(3)
# Observation Space: Box([-1.2  -0.07], [0.6  0.07], (2,), float32)
# Action Space: Discrete(3)
# Observation Space: Box([-1.2  -0.07], [0.6  0.07], (2,), float32)
# Action Space: Discrete(3)
# Observation Space: Box([-1.2  -0.07], [0.6  0.07], (2,), float32)
# Action Space: Discrete(3)
# Observation Space: Box([-1.2  -0.07], [0.6  0.07], (2,), float32)
# Action Space: Discrete(3)
# Observation Space: Box([-1.2  -0.07], [0.6  0.07], (2,), float32)
# Action Space: Discrete(3)
# Observation Space: Box([-1.2  -0.07], [0.6  0.07], (2,), float32)
# Action Space: Discrete(3)
# Observation Space: Box([-1.2  -0.07], [0.6  0.07], (2,), float32)
# Action Space: Discrete(3)
# Observation Space: Box([-1.2  -0.07], [0.6  0.07], (2,), float32)
# Action Space: Discrete(3)
# Observation Space: Box([-1.2  -0.07], [0.6  0.07], (2,), float32)
# Action Space: Discrete(3)
# Observation Space: Box([-1.2  -0.07], [0.6  0.07], (2,), float32)
# Action Space: Discrete(3)
# Observation Space: Box([-1.2  -0.07], [0.6  0.07], (2,), float32)
# Action Space: Discrete(3)
# Observation Space: Box([-1.2  -0.07], [0.6  0.07], (2,), float32)
# Action Space: Discrete(3)
# Observation Space: Box([-1.2  -0.07], [0.6  0.07], (2,), float32)
# Action Space: Discrete(3)
# Observation Space: Box([-1.2  -0.07], [0.6  0.07], (2,), float32)
# Action Space: Discrete(3)
# Observation Space: Box([-1.2  -0.07], [0.6  0.07], (2,), float32)
# Action Space: Discrete(3)
# Observation Space: Box([-1.2  -0.07], [0.6  0.07], (2,), float32)
# Action Space: Discrete(3)
# Observation Space: Box([-1.2  -0.07], [0.6  0.07], (2,), float32)
# Action Space: Discrete(3)
# Observation Space: Box([-1.2  -0.07], [0.6  0.07], (2,), float32)
# Action Space: Discrete(3)
# Observation Space: Box([-1.2  -0.07], [0.6  0.07], (2,), float32)
# Action Space: Discrete(3)
# Observation Space: Box([-1.2  -0.07], [0.6  0.07], (2,), float32)
# Action Space: Discrete(3)
# Observation Space: Box([-1.2  -0.07], [0.6  0.07], (2,), float32)
# Action Space: Discrete(3)
# Observation Space: Box([-1.2  -0.07], [0.6  0.07], (2,), float32)
# Action Space: Discrete(3)
# Observation Space: Box([-1.2  -0.07], [0.6  0.07], (2,), float32)
# Action Space: Discrete(3)
# Observation Space: Box([-1.2  -0.07], [0.6  0.07], (2,), float32)
# Action Space: Discrete(3)
# Observation Space: Box([-1.2  -0.07], [0.6  0.07], (2,), float32)
# Action Space: Discrete(3)
# Observation Space: Box([-1.2  -0.07], [0.6  0.07], (2,), float32)
# Action Space: Discrete(3)
# Observation Space: Box([-1.2  -0.07], [0.6  0.07], (2,), float32)
# Action Space: Discrete(3)
# Observation Space: Box([-1.2  -0.07], [0.6  0.07], (2,), float32)
# Action Space: Discrete(3)
# Observation Space: Box([-1.2  -0.07], [0.6  0.07], (2,), float32)
# Action Space: Discrete(3)
# Observation Space: Box([-1.2  -0.07], [0.6  0.07], (2,), float32)
# Action Space: Discrete(3)
# Observation Space: Box([-1.2  -0.07], [0.6  0.07], (2,), float32)
# Action Space: Discrete(3)
# Observation Space: Box([-1.2  -0.07], [0.6  0.07], (2,), float32)
# Action Space: Discrete(3)
# Observation Space: Box([-1.2  -0.07], [0.6  0.07], (2,), float32)
# Action Space: Discrete(3)
# Observation Space: Box([-1.2  -0.07], [0.6  0.07], (2,), float32)
# Action Space: Discrete(3)
# Observation Space: Box([-1.2  -0.07], [0.6  0.07], (2,), float32)
# Action Space: Discrete(3)
# Observation Space: Box([-1.2  -0.07], [0.6  0.07], (2,), float32)
# Action Space: Discrete(3)
# Observation Space: Box([-1.2  -0.07], [0.6  0.07], (2,), float32)
# Action Space: Discrete(3)
# Observation Space: Box([-1.2  -0.07], [0.6  0.07], (2,), float32)
# Action Space: Discrete(3)
# Observation Space: Box([-1.2  -0.07], [0.6  0.07], (2,), float32)
# Action Space: Discrete(3)
# Observation Space: Box([-1.2  -0.07], [0.6  0.07], (2,), float32)
# Action Space: Discrete(3)
# Observation Space: Box([-1.2  -0.07], [0.6  0.07], (2,), float32)
# Action Space: Discrete(3)
# Observation Space: Box([-1.2  -0.07], [0.6  0.07], (2,), float32)
# Action Space: Discrete(3)
# Observation Space: Box([-1.2  -0.07], [0.6  0.07], (2,), float32)
# Action Space: Discrete(3)
# Observation Space: Box([-1.2  -0.07], [0.6  0.07], (2,), float32)
# Action Space: Discrete(3)
# Observation Space: Box([-1.2  -0.07], [0.6  0.07], (2,), float32)
# Action Space: Discrete(3)
# Observation Space: Box([-1.2  -0.07], [0.6  0.07], (2,), float32)
# Action Space: Discrete(3)
# Observation Space: Box([-1.2  -0.07], [0.6  0.07], (2,), float32)
# Action Space: Discrete(3)
# Observation Space: Box([-1.2  -0.07], [0.6  0.07], (2,), float32)
# Action Space: Discrete(3)
# Observation Space: Box([-1.2  -0.07], [0.6  0.07], (2,), float32)
# Action Space: Discrete(3)
# Observation Space: Box([-1.2  -0.07], [0.6  0.07], (2,), float32)
# Action Space: Discrete(3)
# Observation Space: Box([-1.2  -0.07], [0.6  0.07], (2,), float32)
# Action Space: Discrete(3)
# Observation Space: Box([-1.2  -0.07], [0.6  0.07], (2,), float32)
# Action Space: Discrete(3)
# Observation Space: Box([-1.2  -0.07], [0.6  0.07], (2,), float32)
# Action Space: Discrete(3)
# Observation Space: Box([-1.2  -0.07], [0.6  0.07], (2,), float32)
# Action Space: Discrete(3)
# Observation Space: Box([-1.2  -0.07], [0.6  0.07], (2,), float32)
# Action Space: Discrete(3)
# Observation Space: Box([-1.2  -0.07], [0.6  0.07], (2,), float32)
# Action Space: Discrete(3)
# Observation Space: Box([-1.2  -0.07], [0.6  0.07], (2,), float32)
# Action Space: Discrete(3)
# Observation Space: Box([-1.2  -0.07], [0.6  0.07], (2,), float32)
# Action Space: Discrete(3)
# Observation Space: Box([-1.2  -0.07], [0.6  0.07], (2,), float32)
# Action Space: Discrete(3)
# Observation Space: Box([-1.2  -0.07], [0.6  0.07], (2,), float32)
# Action Space: Discrete(3)
# Observation Space: Box([-1.2  -0.07], [0.6  0.07], (2,), float32)
# Action Space: Discrete(3)
# Observation Space: Box([-1.2  -0.07], [0.6  0.07], (2,), float32)
# Action Space: Discrete(3)
# Observation Space: Box([-1.2  -0.07], [0.6  0.07], (2,), float32)
# Action Space: Discrete(3)
# Observation Space: Box([-1.2  -0.07], [0.6  0.07], (2,), float32)

# %%
from time import sleep
import gymnasium as gym
import random
env = gym.make('MountainCar-v0', render_mode='human')

seed = 0
random.seed(seed)

print(f'Action Space: {env.action_space}')
print(f'Observation Space: {env.observation_space}')

episodes=200
reward_sum=0

state,_ = env.reset()  # Reset the environment
print(state)
for episode in range(episodes):
    env.render()  # Visualize the environment

    position, velocity = state  # Unpack state (position, velocity)

    # Improved Policy: Build momentum to the right to reach the top
    if velocity < 0:
        action = 0  # Push left if velocity is negative
    elif velocity >= 0:
        action = 2  # Push right to gain momentum

    # Taking the action and getting the new state
    state, reward, done, truncated, info = env.step(action)
    reward_sum += reward

    # Environment information
    print(f"Position: {position:.3f}, Velocity: {velocity:.3f}, Action: {action},Reward: {reward}")
    print(f'Reward sum: {reward_sum}')

    # Break if the episode is done
    if done or truncated:
        print(f"Episode ended with total reward: {reward_sum}")
        break

    sleep(0.01)

env.close()
# Out:
# Action Space: Discrete(3)
# Observation Space: Box([-1.2  -0.07], [0.6  0.07], (2,), float32)
# [-0.40737897  0.        ]
# Position: -0.407, Velocity: 0.000, Action: 2,Reward: -1.0
# Reward sum: -1.0
# Position: -0.407, Velocity: 0.000, Action: 2,Reward: -1.0
# Reward sum: -2.0
# Position: -0.407, Velocity: 0.000, Action: 2,Reward: -1.0
# Reward sum: -3.0
# Position: -0.407, Velocity: 0.000, Action: 2,Reward: -1.0
# Reward sum: -4.0
# Position: -0.406, Velocity: 0.001, Action: 2,Reward: -1.0
# Reward sum: -5.0
# Position: -0.405, Velocity: 0.001, Action: 2,Reward: -1.0
# Reward sum: -6.0
# Position: -0.404, Velocity: 0.001, Action: 2,Reward: -1.0
# Reward sum: -7.0
# Position: -0.403, Velocity: 0.001, Action: 2,Reward: -1.0
# Reward sum: -8.0
# Position: -0.402, Velocity: 0.001, Action: 2,Reward: -1.0
# Reward sum: -9.0
# Position: -0.401, Velocity: 0.001, Action: 2,Reward: -1.0
# Reward sum: -10.0
# Position: -0.400, Velocity: 0.001, Action: 2,Reward: -1.0
# Reward sum: -11.0
# Position: -0.398, Velocity: 0.001, Action: 2,Reward: -1.0
# Reward sum: -12.0
# Position: -0.397, Velocity: 0.001, Action: 2,Reward: -1.0
# Reward sum: -13.0
# Position: -0.395, Velocity: 0.002, Action: 2,Reward: -1.0
# Reward sum: -14.0
# Position: -0.394, Velocity: 0.002, Action: 2,Reward: -1.0
# Reward sum: -15.0
# Position: -0.392, Velocity: 0.002, Action: 2,Reward: -1.0
# Reward sum: -16.0
# Position: -0.390, Velocity: 0.002, Action: 2,Reward: -1.0
# Reward sum: -17.0
# Position: -0.389, Velocity: 0.002, Action: 2,Reward: -1.0
# Reward sum: -18.0
# Position: -0.387, Velocity: 0.002, Action: 2,Reward: -1.0
# Reward sum: -19.0
# Position: -0.385, Velocity: 0.002, Action: 2,Reward: -1.0
# Reward sum: -20.0
# Position: -0.384, Velocity: 0.002, Action: 2,Reward: -1.0
# Reward sum: -21.0
# Position: -0.382, Velocity: 0.002, Action: 2,Reward: -1.0
# Reward sum: -22.0
# Position: -0.380, Velocity: 0.002, Action: 2,Reward: -1.0
# Reward sum: -23.0
# Position: -0.378, Velocity: 0.002, Action: 2,Reward: -1.0
# Reward sum: -24.0
# Position: -0.377, Velocity: 0.002, Action: 2,Reward: -1.0
# Reward sum: -25.0
# Position: -0.375, Velocity: 0.002, Action: 2,Reward: -1.0
# Reward sum: -26.0
# Position: -0.374, Velocity: 0.001, Action: 2,Reward: -1.0
# Reward sum: -27.0
# Position: -0.373, Velocity: 0.001, Action: 2,Reward: -1.0
# Reward sum: -28.0
# Position: -0.371, Velocity: 0.001, Action: 2,Reward: -1.0
# Reward sum: -29.0
# Position: -0.370, Velocity: 0.001, Action: 2,Reward: -1.0
# Reward sum: -30.0
# Position: -0.369, Velocity: 0.001, Action: 2,Reward: -1.0
# Reward sum: -31.0
# Position: -0.368, Velocity: 0.001, Action: 2,Reward: -1.0
# Reward sum: -32.0
# Position: -0.367, Velocity: 0.001, Action: 2,Reward: -1.0
# Reward sum: -33.0
# Position: -0.367, Velocity: 0.001, Action: 2,Reward: -1.0
# Reward sum: -34.0
# Position: -0.366, Velocity: 0.001, Action: 2,Reward: -1.0
# Reward sum: -35.0
# Position: -0.366, Velocity: 0.000, Action: 2,Reward: -1.0
# Reward sum: -36.0
# Position: -0.365, Velocity: 0.000, Action: 2,Reward: -1.0
# Reward sum: -37.0
# Position: -0.365, Velocity: 0.000, Action: 2,Reward: -1.0
# Reward sum: -38.0
# Position: -0.365, Velocity: -0.000, Action: 0,Reward: -1.0
# Reward sum: -39.0
# Position: -0.367, Velocity: -0.002, Action: 0,Reward: -1.0
# Reward sum: -40.0
# Position: -0.372, Velocity: -0.004, Action: 0,Reward: -1.0
# Reward sum: -41.0
# Position: -0.378, Velocity: -0.006, Action: 0,Reward: -1.0
# Reward sum: -42.0
# Position: -0.387, Velocity: -0.008, Action: 0,Reward: -1.0
# Reward sum: -43.0
# Position: -0.397, Velocity: -0.010, Action: 0,Reward: -1.0
# Reward sum: -44.0
# Position: -0.409, Velocity: -0.012, Action: 0,Reward: -1.0
# Reward sum: -45.0
# Position: -0.424, Velocity: -0.014, Action: 0,Reward: -1.0
# Reward sum: -46.0
# Position: -0.440, Velocity: -0.016, Action: 0,Reward: -1.0
# Reward sum: -47.0
# Position: -0.457, Velocity: -0.018, Action: 0,Reward: -1.0
# Reward sum: -48.0
# Position: -0.476, Velocity: -0.019, Action: 0,Reward: -1.0
# Reward sum: -49.0
# Position: -0.497, Velocity: -0.020, Action: 0,Reward: -1.0
# Reward sum: -50.0
# Position: -0.518, Velocity: -0.022, Action: 0,Reward: -1.0
# Reward sum: -51.0
# Position: -0.541, Velocity: -0.023, Action: 0,Reward: -1.0
# Reward sum: -52.0
# Position: -0.564, Velocity: -0.024, Action: 0,Reward: -1.0
# Reward sum: -53.0
# Position: -0.589, Velocity: -0.024, Action: 0,Reward: -1.0
# Reward sum: -54.0
# Position: -0.613, Velocity: -0.025, Action: 0,Reward: -1.0
# Reward sum: -55.0
# Position: -0.638, Velocity: -0.025, Action: 0,Reward: -1.0
# Reward sum: -56.0
# Position: -0.664, Velocity: -0.025, Action: 0,Reward: -1.0
# Reward sum: -57.0
# Position: -0.689, Velocity: -0.025, Action: 0,Reward: -1.0
# Reward sum: -58.0
# Position: -0.714, Velocity: -0.025, Action: 0,Reward: -1.0
# Reward sum: -59.0
# Position: -0.739, Velocity: -0.025, Action: 0,Reward: -1.0
# Reward sum: -60.0
# Position: -0.763, Velocity: -0.024, Action: 0,Reward: -1.0
# Reward sum: -61.0
# Position: -0.786, Velocity: -0.024, Action: 0,Reward: -1.0
# Reward sum: -62.0
# Position: -0.809, Velocity: -0.023, Action: 0,Reward: -1.0
# Reward sum: -63.0
# Position: -0.831, Velocity: -0.022, Action: 0,Reward: -1.0
# Reward sum: -64.0
# Position: -0.852, Velocity: -0.021, Action: 0,Reward: -1.0
# Reward sum: -65.0
# Position: -0.872, Velocity: -0.020, Action: 0,Reward: -1.0
# Reward sum: -66.0
# Position: -0.890, Velocity: -0.019, Action: 0,Reward: -1.0
# Reward sum: -67.0
# Position: -0.908, Velocity: -0.017, Action: 0,Reward: -1.0
# Reward sum: -68.0
# Position: -0.924, Velocity: -0.016, Action: 0,Reward: -1.0
# Reward sum: -69.0
# Position: -0.939, Velocity: -0.015, Action: 0,Reward: -1.0
# Reward sum: -70.0
# Position: -0.952, Velocity: -0.013, Action: 0,Reward: -1.0
# Reward sum: -71.0
# Position: -0.964, Velocity: -0.012, Action: 0,Reward: -1.0
# Reward sum: -72.0
# Position: -0.975, Velocity: -0.011, Action: 0,Reward: -1.0
# Reward sum: -73.0
# Position: -0.984, Velocity: -0.009, Action: 0,Reward: -1.0
# Reward sum: -74.0
# Position: -0.991, Velocity: -0.008, Action: 0,Reward: -1.0
# Reward sum: -75.0
# Position: -0.998, Velocity: -0.006, Action: 0,Reward: -1.0
# Reward sum: -76.0
# Position: -1.002, Velocity: -0.005, Action: 0,Reward: -1.0
# Reward sum: -77.0
# Position: -1.006, Velocity: -0.003, Action: 0,Reward: -1.0
# Reward sum: -78.0
# Position: -1.008, Velocity: -0.002, Action: 0,Reward: -1.0
# Reward sum: -79.0
# Position: -1.008, Velocity: -0.000, Action: 0,Reward: -1.0
# Reward sum: -80.0
# Position: -1.007, Velocity: 0.001, Action: 2,Reward: -1.0
# Reward sum: -81.0
# Position: -1.002, Velocity: 0.005, Action: 2,Reward: -1.0
# Reward sum: -82.0
# Position: -0.994, Velocity: 0.008, Action: 2,Reward: -1.0
# Reward sum: -83.0
# Position: -0.982, Velocity: 0.012, Action: 2,Reward: -1.0
# Reward sum: -84.0
# Position: -0.967, Velocity: 0.015, Action: 2,Reward: -1.0
# Reward sum: -85.0
# Position: -0.949, Velocity: 0.018, Action: 2,Reward: -1.0
# Reward sum: -86.0
# Position: -0.927, Velocity: 0.022, Action: 2,Reward: -1.0
# Reward sum: -87.0
# Position: -0.902, Velocity: 0.025, Action: 2,Reward: -1.0
# Reward sum: -88.0
# Position: -0.873, Velocity: 0.028, Action: 2,Reward: -1.0
# Reward sum: -89.0
# Position: -0.842, Velocity: 0.032, Action: 2,Reward: -1.0
# Reward sum: -90.0
# Position: -0.807, Velocity: 0.035, Action: 2,Reward: -1.0
# Reward sum: -91.0
# Position: -0.769, Velocity: 0.038, Action: 2,Reward: -1.0
# Reward sum: -92.0
# Position: -0.729, Velocity: 0.040, Action: 2,Reward: -1.0
# Reward sum: -93.0
# Position: -0.687, Velocity: 0.043, Action: 2,Reward: -1.0
# Reward sum: -94.0
# Position: -0.642, Velocity: 0.045, Action: 2,Reward: -1.0
# Reward sum: -95.0
# Position: -0.595, Velocity: 0.047, Action: 2,Reward: -1.0
# Reward sum: -96.0
# Position: -0.547, Velocity: 0.048, Action: 2,Reward: -1.0
# Reward sum: -97.0
# Position: -0.497, Velocity: 0.049, Action: 2,Reward: -1.0
# Reward sum: -98.0
# Position: -0.447, Velocity: 0.050, Action: 2,Reward: -1.0
# Reward sum: -99.0
# Position: -0.396, Velocity: 0.051, Action: 2,Reward: -1.0
# Reward sum: -100.0
# Position: -0.346, Velocity: 0.051, Action: 2,Reward: -1.0
# Reward sum: -101.0
# Position: -0.295, Velocity: 0.050, Action: 2,Reward: -1.0
# Reward sum: -102.0
# Position: -0.245, Velocity: 0.050, Action: 2,Reward: -1.0
# Reward sum: -103.0
# Position: -0.196, Velocity: 0.049, Action: 2,Reward: -1.0
# Reward sum: -104.0
# Position: -0.148, Velocity: 0.048, Action: 2,Reward: -1.0
# Reward sum: -105.0
# Position: -0.102, Velocity: 0.047, Action: 2,Reward: -1.0
# Reward sum: -106.0
# Position: -0.056, Velocity: 0.045, Action: 2,Reward: -1.0
# Reward sum: -107.0
# Position: -0.013, Velocity: 0.044, Action: 2,Reward: -1.0
# Reward sum: -108.0
# Position: 0.030, Velocity: 0.042, Action: 2,Reward: -1.0
# Reward sum: -109.0
# Position: 0.071, Velocity: 0.041, Action: 2,Reward: -1.0
# Reward sum: -110.0
# Position: 0.110, Velocity: 0.039, Action: 2,Reward: -1.0
# Reward sum: -111.0
# Position: 0.148, Velocity: 0.038, Action: 2,Reward: -1.0
# Reward sum: -112.0
# Position: 0.185, Velocity: 0.037, Action: 2,Reward: -1.0
# Reward sum: -113.0
# Position: 0.220, Velocity: 0.036, Action: 2,Reward: -1.0
# Reward sum: -114.0
# Position: 0.255, Velocity: 0.035, Action: 2,Reward: -1.0
# Reward sum: -115.0
# Position: 0.289, Velocity: 0.034, Action: 2,Reward: -1.0
# Reward sum: -116.0
# Position: 0.322, Velocity: 0.033, Action: 2,Reward: -1.0
# Reward sum: -117.0
# Position: 0.355, Velocity: 0.033, Action: 2,Reward: -1.0
# Reward sum: -118.0
# Position: 0.388, Velocity: 0.033, Action: 2,Reward: -1.0
# Reward sum: -119.0
# Position: 0.420, Velocity: 0.033, Action: 2,Reward: -1.0
# Reward sum: -120.0
# Position: 0.453, Velocity: 0.033, Action: 2,Reward: -1.0
# Reward sum: -121.0
# Position: 0.487, Velocity: 0.033, Action: 2,Reward: -1.0
# Reward sum: -122.0
# Episode ended with total reward: -122.0

# %%
from time import sleep
import gymnasium as gym
import random
env = gym.make('MountainCar-v0', render_mode='human')

seed = 0
random.seed(seed)

print(f'Action Space: {env.action_space}')
print(f'Observation Space: {env.observation_space}')

episodes=200
state,_ = env.reset()  # Reset the environment
reward_sum=0

for episode in range(episodes):
    env.render()  # Visualize the environment

    position, velocity = state  # Unpack state (position, velocity)

    # Improved Policy: Build momentum to the right to reach the top
    if velocity < 0:
        action = 0  # Push left if velocity is negative
    elif velocity >= 0:
        if position < 0:  # Car is in the valley, needs to build momentum
            action = 2  # Push right to gain momentum
        else:  # Car is getting closer to the goal
            action = 0  # No action or apply a small force

    # Taking the action and getting the new state
    state, reward, done, truncated, info = env.step(action)
    reward_sum += reward

    # Environment information
    print(f"Position: {position:.3f}, Velocity: {velocity:.3f}, Action: {action}, Reward: {reward}")
    print(f"Reward sum: {reward_sum}")

    # Break if the episode is done
    if done or truncated:
        print(f"Episode ended with total reward: {reward_sum}")
        break

    sleep(0.01)

env.close()
# Out:
# Action Space: Discrete(3)
# Observation Space: Box([-1.2  -0.07], [0.6  0.07], (2,), float32)
# Position: -0.557, Velocity: 0.000, Action: 2, Reward: -1.0
# Reward sum: -1.0
# Position: -0.556, Velocity: 0.001, Action: 2, Reward: -1.0
# Reward sum: -2.0
# Position: -0.554, Velocity: 0.002, Action: 2, Reward: -1.0
# Reward sum: -3.0
# Position: -0.550, Velocity: 0.004, Action: 2, Reward: -1.0
# Reward sum: -4.0
# Position: -0.545, Velocity: 0.005, Action: 2, Reward: -1.0
# Reward sum: -5.0
# Position: -0.539, Velocity: 0.006, Action: 2, Reward: -1.0
# Reward sum: -6.0
# Position: -0.532, Velocity: 0.007, Action: 2, Reward: -1.0
# Reward sum: -7.0
# Position: -0.523, Velocity: 0.008, Action: 2, Reward: -1.0
# Reward sum: -8.0
# Position: -0.514, Velocity: 0.009, Action: 2, Reward: -1.0
# Reward sum: -9.0
# Position: -0.504, Velocity: 0.010, Action: 2, Reward: -1.0
# Reward sum: -10.0
# Position: -0.493, Velocity: 0.011, Action: 2, Reward: -1.0
# Reward sum: -11.0
# Position: -0.481, Velocity: 0.012, Action: 2, Reward: -1.0
# Reward sum: -12.0
# Position: -0.469, Velocity: 0.012, Action: 2, Reward: -1.0
# Reward sum: -13.0
# Position: -0.456, Velocity: 0.013, Action: 2, Reward: -1.0
# Reward sum: -14.0
# Position: -0.442, Velocity: 0.014, Action: 2, Reward: -1.0
# Reward sum: -15.0
# Position: -0.428, Velocity: 0.014, Action: 2, Reward: -1.0
# Reward sum: -16.0
# Position: -0.414, Velocity: 0.014, Action: 2, Reward: -1.0
# Reward sum: -17.0
# Position: -0.399, Velocity: 0.014, Action: 2, Reward: -1.0
# Reward sum: -18.0
# Position: -0.385, Velocity: 0.015, Action: 2, Reward: -1.0
# Reward sum: -19.0
# Position: -0.370, Velocity: 0.015, Action: 2, Reward: -1.0
# Reward sum: -20.0
# Position: -0.356, Velocity: 0.014, Action: 2, Reward: -1.0
# Reward sum: -21.0
# Position: -0.342, Velocity: 0.014, Action: 2, Reward: -1.0
# Reward sum: -22.0
# Position: -0.328, Velocity: 0.014, Action: 2, Reward: -1.0
# Reward sum: -23.0
# Position: -0.314, Velocity: 0.014, Action: 2, Reward: -1.0
# Reward sum: -24.0
# Position: -0.301, Velocity: 0.013, Action: 2, Reward: -1.0
# Reward sum: -25.0
# Position: -0.289, Velocity: 0.013, Action: 2, Reward: -1.0
# Reward sum: -26.0
# Position: -0.277, Velocity: 0.012, Action: 2, Reward: -1.0
# Reward sum: -27.0
# Position: -0.266, Velocity: 0.011, Action: 2, Reward: -1.0
# Reward sum: -28.0
# Position: -0.255, Velocity: 0.010, Action: 2, Reward: -1.0
# Reward sum: -29.0
# Position: -0.245, Velocity: 0.010, Action: 2, Reward: -1.0
# Reward sum: -30.0
# Position: -0.237, Velocity: 0.009, Action: 2, Reward: -1.0
# Reward sum: -31.0
# Position: -0.229, Velocity: 0.008, Action: 2, Reward: -1.0
# Reward sum: -32.0
# Position: -0.222, Velocity: 0.007, Action: 2, Reward: -1.0
# Reward sum: -33.0
# Position: -0.216, Velocity: 0.006, Action: 2, Reward: -1.0
# Reward sum: -34.0
# Position: -0.211, Velocity: 0.005, Action: 2, Reward: -1.0
# Reward sum: -35.0
# Position: -0.207, Velocity: 0.004, Action: 2, Reward: -1.0
# Reward sum: -36.0
# Position: -0.204, Velocity: 0.003, Action: 2, Reward: -1.0
# Reward sum: -37.0
# Position: -0.202, Velocity: 0.002, Action: 2, Reward: -1.0
# Reward sum: -38.0
# Position: -0.201, Velocity: 0.001, Action: 2, Reward: -1.0
# Reward sum: -39.0
# Position: -0.201, Velocity: -0.000, Action: 0, Reward: -1.0
# Reward sum: -40.0
# Position: -0.204, Velocity: -0.003, Action: 0, Reward: -1.0
# Reward sum: -41.0
# Position: -0.211, Velocity: -0.006, Action: 0, Reward: -1.0
# Reward sum: -42.0
# Position: -0.220, Velocity: -0.009, Action: 0, Reward: -1.0
# Reward sum: -43.0
# Position: -0.232, Velocity: -0.012, Action: 0, Reward: -1.0
# Reward sum: -44.0
# Position: -0.248, Velocity: -0.015, Action: 0, Reward: -1.0
# Reward sum: -45.0
# Position: -0.266, Velocity: -0.018, Action: 0, Reward: -1.0
# Reward sum: -46.0
# Position: -0.286, Velocity: -0.021, Action: 0, Reward: -1.0
# Reward sum: -47.0
# Position: -0.310, Velocity: -0.023, Action: 0, Reward: -1.0
# Reward sum: -48.0
# Position: -0.336, Velocity: -0.026, Action: 0, Reward: -1.0
# Reward sum: -49.0
# Position: -0.364, Velocity: -0.028, Action: 0, Reward: -1.0
# Reward sum: -50.0
# Position: -0.394, Velocity: -0.030, Action: 0, Reward: -1.0
# Reward sum: -51.0
# Position: -0.427, Velocity: -0.032, Action: 0, Reward: -1.0
# Reward sum: -52.0
# Position: -0.461, Velocity: -0.034, Action: 0, Reward: -1.0
# Reward sum: -53.0
# Position: -0.496, Velocity: -0.036, Action: 0, Reward: -1.0
# Reward sum: -54.0
# Position: -0.533, Velocity: -0.037, Action: 0, Reward: -1.0
# Reward sum: -55.0
# Position: -0.571, Velocity: -0.038, Action: 0, Reward: -1.0
# Reward sum: -56.0
# Position: -0.609, Velocity: -0.038, Action: 0, Reward: -1.0
# Reward sum: -57.0
# Position: -0.648, Velocity: -0.039, Action: 0, Reward: -1.0
# Reward sum: -58.0
# Position: -0.687, Velocity: -0.039, Action: 0, Reward: -1.0
# Reward sum: -59.0
# Position: -0.725, Velocity: -0.039, Action: 0, Reward: -1.0
# Reward sum: -60.0
# Position: -0.763, Velocity: -0.038, Action: 0, Reward: -1.0
# Reward sum: -61.0
# Position: -0.801, Velocity: -0.038, Action: 0, Reward: -1.0
# Reward sum: -62.0
# Position: -0.838, Velocity: -0.037, Action: 0, Reward: -1.0
# Reward sum: -63.0
# Position: -0.873, Velocity: -0.036, Action: 0, Reward: -1.0
# Reward sum: -64.0
# Position: -0.908, Velocity: -0.034, Action: 0, Reward: -1.0
# Reward sum: -65.0
# Position: -0.941, Velocity: -0.033, Action: 0, Reward: -1.0
# Reward sum: -66.0
# Position: -0.973, Velocity: -0.032, Action: 0, Reward: -1.0
# Reward sum: -67.0
# Position: -1.003, Velocity: -0.030, Action: 0, Reward: -1.0
# Reward sum: -68.0
# Position: -1.032, Velocity: -0.029, Action: 0, Reward: -1.0
# Reward sum: -69.0
# Position: -1.060, Velocity: -0.027, Action: 0, Reward: -1.0
# Reward sum: -70.0
# Position: -1.085, Velocity: -0.026, Action: 0, Reward: -1.0
# Reward sum: -71.0
# Position: -1.110, Velocity: -0.024, Action: 0, Reward: -1.0
# Reward sum: -72.0
# Position: -1.133, Velocity: -0.023, Action: 0, Reward: -1.0
# Reward sum: -73.0
# Position: -1.154, Velocity: -0.022, Action: 0, Reward: -1.0
# Reward sum: -74.0
# Position: -1.175, Velocity: -0.020, Action: 0, Reward: -1.0
# Reward sum: -75.0
# Position: -1.194, Velocity: -0.019, Action: 0, Reward: -1.0
# Reward sum: -76.0
# Position: -1.200, Velocity: 0.000, Action: 2, Reward: -1.0
# Reward sum: -77.0
# Position: -1.197, Velocity: 0.003, Action: 2, Reward: -1.0
# Reward sum: -78.0
# Position: -1.190, Velocity: 0.006, Action: 2, Reward: -1.0
# Reward sum: -79.0
# Position: -1.180, Velocity: 0.010, Action: 2, Reward: -1.0
# Reward sum: -80.0
# Position: -1.167, Velocity: 0.013, Action: 2, Reward: -1.0
# Reward sum: -81.0
# Position: -1.151, Velocity: 0.016, Action: 2, Reward: -1.0
# Reward sum: -82.0
# Position: -1.131, Velocity: 0.020, Action: 2, Reward: -1.0
# Reward sum: -83.0
# Position: -1.108, Velocity: 0.023, Action: 2, Reward: -1.0
# Reward sum: -84.0
# Position: -1.081, Velocity: 0.027, Action: 2, Reward: -1.0
# Reward sum: -85.0
# Position: -1.051, Velocity: 0.030, Action: 2, Reward: -1.0
# Reward sum: -86.0
# Position: -1.018, Velocity: 0.034, Action: 2, Reward: -1.0
# Reward sum: -87.0
# Position: -0.980, Velocity: 0.037, Action: 2, Reward: -1.0
# Reward sum: -88.0
# Position: -0.940, Velocity: 0.041, Action: 2, Reward: -1.0
# Reward sum: -89.0
# Position: -0.896, Velocity: 0.044, Action: 2, Reward: -1.0
# Reward sum: -90.0
# Position: -0.849, Velocity: 0.047, Action: 2, Reward: -1.0
# Reward sum: -91.0
# Position: -0.798, Velocity: 0.050, Action: 2, Reward: -1.0
# Reward sum: -92.0
# Position: -0.745, Velocity: 0.053, Action: 2, Reward: -1.0
# Reward sum: -93.0
# Position: -0.690, Velocity: 0.056, Action: 2, Reward: -1.0
# Reward sum: -94.0
# Position: -0.632, Velocity: 0.058, Action: 2, Reward: -1.0
# Reward sum: -95.0
# Position: -0.572, Velocity: 0.060, Action: 2, Reward: -1.0
# Reward sum: -96.0
# Position: -0.511, Velocity: 0.061, Action: 2, Reward: -1.0
# Reward sum: -97.0
# Position: -0.449, Velocity: 0.062, Action: 2, Reward: -1.0
# Reward sum: -98.0
# Position: -0.387, Velocity: 0.062, Action: 2, Reward: -1.0
# Reward sum: -99.0
# Position: -0.324, Velocity: 0.062, Action: 2, Reward: -1.0
# Reward sum: -100.0
# Position: -0.262, Velocity: 0.062, Action: 2, Reward: -1.0
# Reward sum: -101.0
# Position: -0.201, Velocity: 0.061, Action: 2, Reward: -1.0
# Reward sum: -102.0
# Position: -0.141, Velocity: 0.060, Action: 2, Reward: -1.0
# Reward sum: -103.0
# Position: -0.082, Velocity: 0.059, Action: 2, Reward: -1.0
# Reward sum: -104.0
# Position: -0.025, Velocity: 0.057, Action: 2, Reward: -1.0
# Reward sum: -105.0
# Position: 0.031, Velocity: 0.056, Action: 0, Reward: -1.0
# Reward sum: -106.0
# Position: 0.084, Velocity: 0.052, Action: 0, Reward: -1.0
# Reward sum: -107.0
# Position: 0.133, Velocity: 0.049, Action: 0, Reward: -1.0
# Reward sum: -108.0
# Position: 0.178, Velocity: 0.046, Action: 0, Reward: -1.0
# Reward sum: -109.0
# Position: 0.221, Velocity: 0.043, Action: 0, Reward: -1.0
# Reward sum: -110.0
# Position: 0.261, Velocity: 0.040, Action: 0, Reward: -1.0
# Reward sum: -111.0
# Position: 0.297, Velocity: 0.037, Action: 0, Reward: -1.0
# Reward sum: -112.0
# Position: 0.332, Velocity: 0.034, Action: 0, Reward: -1.0
# Reward sum: -113.0
# Position: 0.364, Velocity: 0.032, Action: 0, Reward: -1.0
# Reward sum: -114.0
# Position: 0.393, Velocity: 0.030, Action: 0, Reward: -1.0
# Reward sum: -115.0
# Position: 0.421, Velocity: 0.028, Action: 0, Reward: -1.0
# Reward sum: -116.0
# Position: 0.447, Velocity: 0.026, Action: 0, Reward: -1.0
# Reward sum: -117.0
# Position: 0.472, Velocity: 0.024, Action: 0, Reward: -1.0
# Reward sum: -118.0
# Position: 0.495, Velocity: 0.023, Action: 0, Reward: -1.0
# Reward sum: -119.0
# Episode ended with total reward: -119.0

# %%
import gymnasium as gym 
import ale_py

gym.register_envs(ale_py)

# %%
env = gym.make("ALE/Breakout-v5", render_mode="rgb_array")
obs, info = env.reset()

raw_frame = env.render()
print(type(raw_frame))
print(raw_frame.shape)
# Out:
# <class 'numpy.ndarray'>
# (210, 160, 3)

# %%
# convert to RGB scale 
import cv2

def to_grayScale(frame_rgb):
    return cv2.cvtColor(frame_rgb, cv2.COLOR_RGB2GRAY)

gray = to_grayScale(raw_frame)
print(gray.shape)
# Out:
# (210, 160)

# %%
#Step4 Down-size sample to 110,84

def downSample(frame_gray):
    return cv2.resize(frame_gray, (84,110), interpolation =cv2.INTER_LINEAR) 
    # resize takes width, height.

# %%
downsized = downSample(gray)
print(downsized.shape)
# Out:
# (110, 84)

# %%
# crop the image to 84 x84 

def crop(frame_110x84):
    top = 110-84
    return frame_110x84[top:top + 84, 0:84]  # ndarray operations

# %%
cropped = crop(downsized)
print(cropped.shape)
# Out:
# (84, 84)

# %%
# stacking the last four frames  
   # this is required because single frame will not tell the direction and velocity of the ball or enemy velocity.  stacking last 4 will give implict
    # motion positon without needeing recurrent architecture 
from collections import deque
import numpy as np

frame_stack = deque(maxlen=4)

def stackFrames(new_cropped_frame):
    frame_stack.append(new_cropped_frame)
    while len(frame_stack) < 4 :
        frame_stack.append(new_cropped_frame)
    return np.stack(frame_stack, axis=-1)

state = stackFrames(cropped)
print(state.shape)
print(type(state))
# Out:
# (84, 84, 4)
# <class 'numpy.ndarray'>
